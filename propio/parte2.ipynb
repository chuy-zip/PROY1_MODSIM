# %%
Pkg.add.(["JuMP","HiGHS","LinearAlgebra","DelimitedFiles","Random","StatsBase","Graphs","Plots"])
# Out:
#     Updating registry at `C:\Users\MSI\.julia\registries\General.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\MSI\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\MSI\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\MSI\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\MSI\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#     Updating `C:\Users\MSI\.julia\environments\v1.11\Project.toml`
#   [37e2e46d] + LinearAlgebra v1.11.0
#   No Changes to `C:\Users\MSI\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#    Installed DelimitedFiles ─ v1.9.1
#     Updating `C:\Users\MSI\.julia\environments\v1.11\Project.toml`
#   [8bb1440f] + DelimitedFiles v1.9.1
#     Updating `C:\Users\MSI\.julia\environments\v1.11\Manifest.toml`
#   [8bb1440f] + DelimitedFiles v1.9.1
# Precompiling project...
#    1246.4 ms  ✓ DelimitedFiles
#   1 dependency successfully precompiled in 2 seconds. 160 already precompiled.
#    Resolving package versions...
#     Updating `C:\Users\MSI\.julia\environments\v1.11\Project.toml`
#   [9a3f8284] + Random v1.11.0
#   No Changes to `C:\Users\MSI\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#    Installed StatsAPI ────────── v1.7.1
#    Installed PtrArrays ───────── v1.3.0
#    Installed Missings ────────── v1.2.0
#    Installed AliasTables ─────── v1.1.3
#    Installed SortingAlgorithms ─ v1.2.2
#    Installed StatsBase ───────── v0.34.6
#     Updating `C:\Users\MSI\.julia\environments\v1.11\Project.toml`
#   [2913bbd2] + StatsBase v0.34.6
#     Updating `C:\Users\MSI\.julia\environments\v1.11\Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [e1d29d7a] + Missings v1.2.0
#   [43287f4e] + PtrArrays v1.3.0
#   [a2af1166] + SortingAlgorithms v1.2.2
#   [82ae8749] + StatsAPI v1.7.1
#   [2913bbd2] + StatsBase v0.34.6
# Precompiling project...
#     505.0 ms  ✓ StatsAPI
#     452.7 ms  ✓ PtrArrays
#     570.0 ms  ✓ Missings
#     625.9 ms  ✓ SortingAlgorithms
#     466.4 ms  ✓ AliasTables
#    1672.6 ms  ✓ StatsBase
#   6 dependencies successfully precompiled in 3 seconds. 161 already precompiled.
#    Resolving package versions...
#    Installed Inflate ─────── v0.1.5
#    Installed SimpleTraits ── v0.9.5
#    Installed ArnoldiMethod ─ v0.4.0
#    Installed StaticArrays ── v1.9.15
#    Installed Graphs ──────── v1.13.1
#     Updating `C:\Users\MSI\.julia\environments\v1.11\Project.toml`
#   [86223c79] + Graphs v1.13.1
#     Updating `C:\Users\MSI\.julia\environments\v1.11\Manifest.toml`
#   [ec485272] + ArnoldiMethod v0.4.0
#   [86223c79] + Graphs v1.13.1
#   [d25df0c9] + Inflate v0.1.5
#   [699a6c99] + SimpleTraits v0.9.5
#   [90137ffa] + StaticArrays v1.9.15
#   [1a1011a3] + SharedArrays v1.11.0
# Precompiling project...
#     990.8 ms  ✓ Inflate
#    1282.9 ms  ✓ SimpleTraits
#    5580.5 ms  ✓ StaticArrays
#     881.8 ms  ✓ DifferentiationInterface → DifferentiationInterfaceStaticArraysExt
#     897.0 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#     996.5 ms  ✓ Adapt → AdaptStaticArraysExt
#    1093.8 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    1129.1 ms  ✓ Accessors → StaticArraysExt
#    1125.3 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#    1302.6 ms  ✓ ArnoldiMethod
#    3018.3 ms  ✓ Graphs
#   11 dependencies successfully precompiled in 11 seconds. 168 already precompiled.
#    Resolving package versions...
#    Installed x265_jll ───────────────────── v4.1.0+0
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed libfdk_aac_jll ─────────────── v2.0.4+0
#    Installed Libmount_jll ───────────────── v2.41.2+0
#    Installed LERC_jll ───────────────────── v4.0.1+0
#    Installed GR_jll ─────────────────────── v0.73.17+0
#    Installed JpegTurbo_jll ──────────────── v3.1.3+0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed Measures ───────────────────── v0.3.2
#    Installed ConcurrentUtilities ────────── v2.5.0
#    Installed Opus_jll ───────────────────── v1.5.2+0
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Contour ────────────────────── v0.6.3
#    Installed ColorSchemes ───────────────── v3.31.0
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.2+0
#    Installed Xorg_xcb_util_image_jll ────── v0.4.1+0
#    Installed PlotUtils ──────────────────── v1.4.3
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed OpenSSL ────────────────────── v1.5.0
#    Installed HTTP ───────────────────────── v1.10.19
#    Installed Xorg_xcb_util_jll ──────────── v0.4.1+0
#    Installed Cairo_jll ──────────────────── v1.18.5+0
#    Installed Xorg_libSM_jll ─────────────── v1.2.6+0
#    Installed Fontconfig_jll ─────────────── v2.17.1+0
#    Installed Xorg_libxkbfile_jll ────────── v1.1.3+0
#    Installed Xorg_libXinerama_jll ───────── v1.1.6+0
#    Installed EpollShim_jll ──────────────── v0.0.20230411+1
#    Installed Pango_jll ──────────────────── v1.56.4+0
#    Installed Xorg_libXau_jll ────────────── v1.0.13+0
#    Installed FFMPEG ─────────────────────── v0.4.4
#    Installed Showoff ────────────────────── v1.0.3
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.1+0
#    Installed xkbcommon_jll ──────────────── v1.9.2+0
#    Installed SimpleBufferStream ─────────── v1.2.0
#    Installed HarfBuzz_jll ───────────────── v8.5.1+0
#    Installed XZ_jll ─────────────────────── v5.8.1+0
#    Installed LZO_jll ────────────────────── v2.10.3+0
#    Installed PlotThemes ─────────────────── v3.3.0
#    Installed fzf_jll ────────────────────── v0.61.1+0
#    Installed FriBidi_jll ────────────────── v1.0.17+0
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed MbedTLS ────────────────────── v1.1.9
#    Installed GLFW_jll ───────────────────── v3.4.0+2
#    Installed FreeType2_jll ──────────────── v2.13.4+0
#    Installed x264_jll ───────────────────── v10164.0.1+0
#    Installed JLFzf ──────────────────────── v0.1.11
#    Installed Xorg_libxcb_jll ────────────── v1.17.1+0
#    Installed Colors ─────────────────────── v0.13.1
#    Installed libpng_jll ─────────────────── v1.6.50+0
#    Installed libaom_jll ─────────────────── v3.12.1+0
#    Installed mtdev_jll ──────────────────── v1.1.7+0
#    Installed ColorTypes ─────────────────── v0.12.1
#    Installed Scratch ────────────────────── v1.3.0
#    Installed eudev_jll ──────────────────── v3.2.14+0
#    Installed ExceptionUnwrapping ────────── v0.1.11
#    Installed Xorg_libXext_jll ───────────── v1.3.7+0
#    Installed Dbus_jll ───────────────────── v1.16.2+0
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed Plots ──────────────────────── v1.41.1
#    Installed Expat_jll ──────────────────── v2.7.1+0
#    Installed Zstd_jll ───────────────────── v1.5.7+1
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.6+0
#    Installed Libtiff_jll ────────────────── v4.7.2+0
#    Installed Libffi_jll ─────────────────── v3.4.7+0
#    Installed Xorg_libXrender_jll ────────── v0.9.12+0
#    Installed Ogg_jll ────────────────────── v1.3.6+0
#    Installed Format ─────────────────────── v1.3.7
#    Installed ColorVectorSpace ───────────── v0.11.0
#    Installed libevdev_jll ───────────────── v1.13.4+0
#    Installed libinput_jll ───────────────── v1.28.1+0
#    Installed GR ─────────────────────────── v0.73.17
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed Xorg_libXi_jll ─────────────── v1.8.3+0
#    Installed Ghostscript_jll ────────────── v9.55.1+0
#    Installed Xorg_libXcursor_jll ────────── v1.2.4+0
#    Installed Qt6ShaderTools_jll ─────────── v6.8.2+1
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.10+0
#    Installed Libuuid_jll ────────────────── v2.41.2+0
#    Installed Qt6Declarative_jll ─────────── v6.8.2+1
#    Installed Xorg_libICE_jll ────────────── v1.1.2+0
#    Installed StableRNGs ─────────────────── v1.0.3
#    Installed libass_jll ─────────────────── v0.17.4+0
#    Installed Graphite2_jll ──────────────── v1.3.15+0
#    Installed Wayland_jll ────────────────── v1.24.0+0
#    Installed OpenSSL_jll ────────────────── v3.5.4+0
#    Installed Latexify ───────────────────── v0.16.10
#    Installed Pixman_jll ─────────────────── v0.44.2+0
#    Installed Xorg_xtrans_jll ────────────── v1.6.0+0
#    Installed BitFlags ───────────────────── v0.1.9
#    Installed Xorg_xkeyboard_config_jll ──── v2.44.0+0
#    Installed LLVMOpenMP_jll ─────────────── v18.1.8+0
#    Installed FFMPEG_jll ─────────────────── v7.1.1+0
#    Installed Qt6Wayland_jll ─────────────── v6.8.2+1
#    Installed Xorg_libXfixes_jll ─────────── v6.0.2+0
#    Installed FixedPointNumbers ──────────── v0.8.5
#    Installed LAME_jll ───────────────────── v3.100.3+0
#    Installed Xorg_libXrandr_jll ─────────── v1.5.5+0
#    Installed Libiconv_jll ───────────────── v1.18.0+0
#    Installed GettextRuntime_jll ─────────── v0.22.4+0
#    Installed Qt6Base_jll ────────────────── v6.8.2+1
#    Installed libvorbis_jll ──────────────── v1.3.8+0
#    Installed URIs ───────────────────────── v1.6.1
#    Installed Xorg_libX11_jll ────────────── v1.8.12+0
#    Installed Glib_jll ───────────────────── v2.86.0+0
#    Installed Libglvnd_jll ───────────────── v1.7.1+1
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed Xorg_libXdmcp_jll ──────────── v1.1.6+0
#     Updating `C:\Users\MSI\.julia\environments\v1.11\Project.toml`
#   [91a5bcdd] + Plots v1.41.1
#     Updating `C:\Users\MSI\.julia\environments\v1.11\Manifest.toml`
#   [d1d4a3ce] + BitFlags v0.1.9
#   [35d6a980] + ColorSchemes v3.31.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.1
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [d38c429a] + Contour v0.6.3
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.4
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.17
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.19
#   [1019f520] + JLFzf v0.1.11
#   [23fbe1c1] + Latexify v0.16.10
#   [739be429] + MbedTLS v1.1.9
#   [442fdcdd] + Measures v0.3.2
#   [4d8831e6] + OpenSSL v1.5.0
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.3
#   [91a5bcdd] + Plots v1.41.1
#   [01d81517] + RecipesPipeline v0.6.12
#   [05181044] + RelocatableFolders v1.0.1
#   [6c6a2e73] + Scratch v1.3.0
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [860ef19b] + StableRNGs v1.0.3
#   [62fd8b95] + TensorCore v0.1.1
#   [5c2747f8] + URIs v1.6.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [41fe7b60] + Unzip v0.2.0
#   [83423d85] + Cairo_jll v1.18.5+0
#   [ee1fde0b] + Dbus_jll v1.16.2+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.7.1+0
#   [b22a6f82] + FFMPEG_jll v7.1.1+0
#   [a3f928ae] + Fontconfig_jll v2.17.1+0
#   [d7e528f0] + FreeType2_jll v2.13.4+0
#   [559328eb] + FriBidi_jll v1.0.17+0
#   [0656b61e] + GLFW_jll v3.4.0+2
#   [d2c73de3] + GR_jll v0.73.17+0
#   [b0724c58] + GettextRuntime_jll v0.22.4+0
#   [61579ee1] + Ghostscript_jll v9.55.1+0
#   [7746bdde] + Glib_jll v2.86.0+0
#   [3b182d85] + Graphite2_jll v1.3.15+0
#   [2e76f6c2] + HarfBuzz_jll v8.5.1+0
#   [aacddb02] + JpegTurbo_jll v3.1.3+0
#   [c1c5ebd0] + LAME_jll v3.100.3+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.8+0
#   [dd4b983a] + LZO_jll v2.10.3+0
#   [e9f186c6] + Libffi_jll v3.4.7+0
#   [7e76a0d4] + Libglvnd_jll v1.7.1+1
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [4b2f31a3] + Libmount_jll v2.41.2+0
#   [89763e89] + Libtiff_jll v4.7.2+0
#   [38a345b3] + Libuuid_jll v2.41.2+0
#   [e7412a2a] + Ogg_jll v1.3.6+0
#   [458c3c95] + OpenSSL_jll v3.5.4+0
#   [91d4177d] + Opus_jll v1.5.2+0
#   [36c8627f] + Pango_jll v1.56.4+0
# ⌅ [30392449] + Pixman_jll v0.44.2+0
#   [c0090381] + Qt6Base_jll v6.8.2+1
#   [629bc702] + Qt6Declarative_jll v6.8.2+1
#   [ce943373] + Qt6ShaderTools_jll v6.8.2+1
#   [e99dba38] + Qt6Wayland_jll v6.8.2+1
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.24.0+0
#   [ffd25f8a] + XZ_jll v5.8.1+0
#   [f67eecfb] + Xorg_libICE_jll v1.1.2+0
#   [c834827a] + Xorg_libSM_jll v1.2.6+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.12+0
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.13+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.4+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.6+0
#   [1082639a] + Xorg_libXext_jll v1.3.7+0
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.2+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.3+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.6+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.5+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.12+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.1+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.3+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.6+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.1+0
#   [2def613f] + Xorg_xcb_util_jll v0.4.1+0
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.1+0
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.10+0
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.2+0
#   [35661453] + Xorg_xkbcomp_jll v1.4.7+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.44.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.6.0+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [35ca27e7] + eudev_jll v3.2.14+0
#   [214eeab7] + fzf_jll v0.61.1+0
#   [a4ae2306] + libaom_jll v3.12.1+0
#   [0ac62f75] + libass_jll v0.17.4+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.13.4+0
#   [f638f0a6] + libfdk_aac_jll v2.0.4+0
#   [36db933b] + libinput_jll v1.28.1+0
#   [b53b4c65] + libpng_jll v1.6.50+0
#   [f27f6e37] + libvorbis_jll v1.3.8+0
#   [009596ad] + mtdev_jll v1.1.7+0
#   [1270edf5] + x264_jll v10164.0.1+0
#   [dfaa095f] + x265_jll v4.1.0+0
#   [d8fb68d0] + xkbcommon_jll v1.9.2+0
#   [3fa0cd96] + REPL v1.11.0
#   [f489334b] + StyledStrings v1.11.0
#   [efcefdf7] + PCRE2_jll v10.42.0+1
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#     764.0 ms  ✓ TensorCore
#     727.2 ms  ✓ SimpleBufferStream
#     814.7 ms  ✓ Contour
#     799.5 ms  ✓ Measures
#     790.0 ms  ✓ StableRNGs
#     937.2 ms  ✓ Unzip
#     934.8 ms  ✓ URIs
#    1052.5 ms  ✓ Grisu
#    1328.5 ms  ✓ Format
#     515.0 ms  ✓ BitFlags
#     554.5 ms  ✓ Scratch
#     915.0 ms  ✓ ConcurrentUtilities
#     767.5 ms  ✓ OpenSSL_jll
#     929.4 ms  ✓ ExceptionUnwrapping
#     748.3 ms  ✓ Libmount_jll
#    1250.3 ms  ✓ MbedTLS
#     830.2 ms  ✓ Graphite2_jll
#     719.1 ms  ✓ EpollShim_jll
#     864.5 ms  ✓ LLVMOpenMP_jll
#     770.3 ms  ✓ Xorg_libICE_jll
#     761.5 ms  ✓ Xorg_libXau_jll
#     808.8 ms  ✓ libpng_jll
#     845.0 ms  ✓ libfdk_aac_jll
#    1969.5 ms  ✓ UnicodeFun
#     898.9 ms  ✓ LAME_jll
#     827.2 ms  ✓ LERC_jll
#    2494.2 ms  ✓ FixedPointNumbers
#     817.3 ms  ✓ fzf_jll
#     935.4 ms  ✓ JpegTurbo_jll
#     964.1 ms  ✓ XZ_jll
#     861.0 ms  ✓ mtdev_jll
#     810.0 ms  ✓ Xorg_libXdmcp_jll
#    1025.2 ms  ✓ Ogg_jll
#     884.8 ms  ✓ x264_jll
#     909.3 ms  ✓ x265_jll
#     791.3 ms  ✓ libaom_jll
#     808.1 ms  ✓ Zstd_jll
#     845.2 ms  ✓ Expat_jll
#     759.9 ms  ✓ LZO_jll
#     792.7 ms  ✓ Xorg_xtrans_jll
#     807.9 ms  ✓ Opus_jll
#     737.9 ms  ✓ libevdev_jll
#     901.9 ms  ✓ Libiconv_jll
#     783.1 ms  ✓ eudev_jll
#     903.9 ms  ✓ Libffi_jll
#     738.2 ms  ✓ Libuuid_jll
#     853.1 ms  ✓ FriBidi_jll
#     894.6 ms  ✓ FreeType2_jll
#     655.8 ms  ✓ RelocatableFolders
#     666.5 ms  ✓ Showoff
#     605.8 ms  ✓ Xorg_libSM_jll
#     701.7 ms  ✓ Pixman_jll
#     624.1 ms  ✓ Xorg_libxcb_jll
#     859.4 ms  ✓ libvorbis_jll
#     780.6 ms  ✓ Dbus_jll
#     970.6 ms  ✓ Libtiff_jll
#    1325.9 ms  ✓ JLFzf
#    1744.1 ms  ✓ OpenSSL
#     990.6 ms  ✓ GettextRuntime_jll
#    1835.2 ms  ✓ ColorTypes
#    1449.8 ms  ✓ Ghostscript_jll
#     820.4 ms  ✓ libinput_jll
#     712.4 ms  ✓ Wayland_jll
#     701.6 ms  ✓ Xorg_xcb_util_jll
#     691.8 ms  ✓ Xorg_libX11_jll
#     949.7 ms  ✓ Fontconfig_jll
#    1015.8 ms  ✓ ColorTypes → StyledStringsExt
#     767.6 ms  ✓ Xorg_xcb_util_image_jll
#     760.5 ms  ✓ Xorg_xcb_util_keysyms_jll
#    1256.0 ms  ✓ Glib_jll
#     823.8 ms  ✓ Xorg_xcb_util_renderutil_jll
#     873.4 ms  ✓ Xorg_xcb_util_wm_jll
#     871.0 ms  ✓ Xorg_libXrender_jll
#     862.8 ms  ✓ Xorg_libXext_jll
#     957.0 ms  ✓ Xorg_libXfixes_jll
#     815.8 ms  ✓ Xorg_libxkbfile_jll
#    2198.6 ms  ✓ ColorVectorSpace
#     926.4 ms  ✓ Xorg_xcb_util_cursor_jll
#     913.7 ms  ✓ Xorg_libXinerama_jll
#     904.2 ms  ✓ Xorg_libXrandr_jll
#     925.6 ms  ✓ Libglvnd_jll
#     776.6 ms  ✓ Xorg_libXcursor_jll
#    1344.3 ms  ✓ Cairo_jll
#     839.0 ms  ✓ Xorg_xkbcomp_jll
#     850.0 ms  ✓ Xorg_libXi_jll
#    3570.3 ms  ✓ Latexify
#     895.2 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#     564.8 ms  ✓ Xorg_xkeyboard_config_jll
#    1172.9 ms  ✓ HarfBuzz_jll
#    4637.1 ms  ✓ Colors
#    1004.5 ms  ✓ Latexify → SparseArraysExt
#     630.1 ms  ✓ xkbcommon_jll
#     839.1 ms  ✓ libass_jll
#     745.3 ms  ✓ Vulkan_Loader_jll
#     984.1 ms  ✓ Pango_jll
#    1097.9 ms  ✓ SparseMatrixColorings → SparseMatrixColoringsColorsExt
#     569.3 ms  ✓ libdecor_jll
#    1139.7 ms  ✓ FFMPEG_jll
#    1097.2 ms  ✓ Qt6Base_jll
#     632.1 ms  ✓ GLFW_jll
#    1117.9 ms  ✓ FFMPEG
#    1271.5 ms  ✓ Qt6ShaderTools_jll
#    1160.8 ms  ✓ GR_jll
#    3552.7 ms  ✓ ColorSchemes
#    1604.7 ms  ✓ Qt6Declarative_jll
#     458.6 ms  ✓ Qt6Wayland_jll
#   13165.0 ms  ✓ HTTP
#    6977.3 ms  ✓ PlotUtils
#    3343.1 ms  ✓ GR
#    2362.0 ms  ✓ PlotThemes
#    2987.4 ms  ✓ RecipesPipeline
#   39535.9 ms  ✓ Plots
#   112 dependencies successfully precompiled in 65 seconds. 183 already precompiled.
# 8-element Vector{Nothing}:
#  nothing
#  nothing
#  nothing
#  nothing
#  nothing
#  nothing
#  nothing
#  nothing

# %%
using Pkg
using JuMP 
using HiGHS
using LinearAlgebra
using Random
using Graphs
using Plots
using Printf

Random.seed!(42)

const DATA_INPUT_DIR = joinpath("..","data","input")
const OUTPUT_DIR     = joinpath("output","archipelago120")
const INSTANCE_NAME  = "archipelago120"

mkpath(OUTPUT_DIR)
# Out:
# "output\\archipelago120"

# %%
function leer_archivo_tsp(path::AbstractString)
    ids = Int[]
    X   = Float64[]
    Y   = Float64[]
    in_coords = false
    open(path, "r") do f
        for ln in eachline(f)
            if occursin("NODE_COORD_SECTION", ln); in_coords = true; continue; end
            if occursin("EOF", ln); break; end
            if in_coords
                tok = split(strip(ln))
                if length(tok) >= 3
                    push!(ids, parse(Int, tok[1]))
                    push!(X, parse(Float64, tok[2]))
                    push!(Y, parse(Float64, tok[3]))
                end
            end
        end
    end
    return ids, hcat(X,Y)
end

function euclid2(a::AbstractVector, b::AbstractVector)
    dx = a[1]-b[1]; dy = a[2]-b[2]
    return sqrt(dx*dx + dy*dy)
end

function matriz_distancias(coords::AbstractMatrix)
    n = size(coords,1)
    D = zeros(Float64, n, n)
    for i in 1:n, j in i+1:n
        d = euclid2(coords[i,:], coords[j,:])
        D[i,j] = d; D[j,i] = d
    end
    return D
end

tsp_path = joinpath(DATA_INPUT_DIR, INSTANCE_NAME*".tsp")
ids, coords = leer_archivo_tsp(tsp_path)
n = length(ids)
distancias = matriz_distancias(coords)
println("Instancia: $INSTANCE_NAME  | n = $n")
# Out:
# Instancia: archipelago120  | n = 120

# %%
# helpers DFJ
# Grafo inducido por solución actual
function componentes_from_x(xvals::Matrix{Float64}; thr=0.5)
    g = SimpleGraph(n)
    for i in 1:n, j in i+1:n
        if xvals[i,j] > thr || xvals[j,i] > thr
            add_edge!(g, i, j)
        end
    end
    return connected_components(g)
end

# Agrega corte DFJ para un subconjunto S al menos 1 arco sale de S y 1 entra a S
function agregar_corte!(model::Model, x, S::Vector{Int})
    V = collect(1:n)
    T = setdiff(V, S)
    if !isempty(T) && !isempty(S)
        @constraint(model, sum(x[i,j] for i in S, j in T) >= 1)
        @constraint(model, sum(x[i,j] for i in T, j in S) >= 1)
        return 2
    end
    return 0
end

# Reconstruye tour dirigido desde x (arranca en el nodo 1)
function tour_from_x(xvals::Matrix{Float64})
    nxt = zeros(Int, n)
    for i in 1:n
        j = argmax(xvals[i, :])
        nxt[i] = j
    end
    tour = Int[]
    seen = falses(n)
    cur = 1
    for _ in 1:n
        push!(tour, cur)
        seen[cur] = true
        cur = nxt[cur]
        if seen[cur]; break; end
    end
    return tour
end

function costo_tour(tour::Vector{Int}, D::Matrix{Float64})
    c = 0.0
    for k in 1:length(tour)-1
        c += D[tour[k], tour[k+1]]
    end
    c += D[tour[end], tour[1]]
    return c
end
# Out:
# costo_tour (generic function with 1 method)

# %%
### mejora local 2-opt rápida sobre tour
function two_opt!(tour::Vector{Int}, D::Matrix{Float64})
    n = length(tour)
    improved = true
    while improved
        improved = false
        for i in 1:n-3
            for j in i+2:n-1
                a,b = tour[i], tour[i+1]
                c,d = tour[j], tour[j+1]
                Δ = (D[a,c] + D[b,d]) - (D[a,b] + D[c,d])
                if Δ < -1e-9
                    reverse!(tour, i+1, j)
                    improved = true
                end
            end
        end
    end
    return tour
end
# Out:
# two_opt! (generic function with 1 method)

# %%
# modelo JuMP 
model = Model(HiGHS.Optimizer)

# Atributos del solver
set_optimizer_attribute(model, "time_limit", 3600.0)
set_optimizer_attribute(model, "threads", 4)
set_optimizer_attribute(model, "parallel", "on")
set_optimizer_attribute(model, "presolve", "on")
set_optimizer_attribute(model, "mip_rel_gap", 0.5)
set_optimizer_attribute(model, "mip_abs_gap", 50.0)
set_optimizer_attribute(model, "mip_max_nodes", 80000)

@variable(model, x[1:n,1:n], Bin)
for i in 1:n
    @constraint(model, x[i,i] == 0)
end

@constraint(model, salida[i in 1:n], sum(x[i,j] for j in 1:n) == 1)
@constraint(model, entrada[i in 1:n], sum(x[j,i] for j in 1:n) == 1)

@objective(model, Min, sum(distancias[i,j] * x[i,j] for i in 1:n, j in 1:n))
# Out:
# 28.43132527688427 x[1,2] + 45.66751288388713 x[1,3] + 33.03972398492467 x[1,4] + 2.966042649727066 x[1,5] + 69.64106858025657 x[1,6] + 36.03355204528134 x[1,7] + 40.9241523308669 x[1,8] + 22.758938573668097 x[1,9] + 38.990336546380306 x[1,10] + 46.61866720531595 x[1,11] + 76.31359315351358 x[1,12] + 24.490442237738375 x[1,13] + 65.31925079943888 x[1,14] + 40.78385819169149 x[1,15] + 12.348281540360123 x[1,16] + 50.115343448888034 x[1,17] + 54.09828645160578 x[1,18] + 45.549715487585644 x[1,19] + 12.188990811383887 x[1,20] + 353.06600340446255 x[1,21] + 341.7059987255126 x[1,22] + 343.24594753762204 x[1,23] + 367.60767332850924 x[1,24] + 343.05757513426227 x[1,25] + 392.8445591744907 x[1,26] + 341.55620924527193 x[1,27] + 355.011399155013 x[1,28] + 366.4324110187307 x[1,29] + 368.2163185751006 x[1,30] + 371.83019647145386 x[1,31] + [[...14220 terms omitted...]] + 605.891483225338 x[120,90] + 561.5889239523871 x[120,91] + 565.0023266191033 x[120,92] + 578.2895444965263 x[120,93] + 563.312327016727 x[120,94] + 536.3732544422774 x[120,95] + 568.2018261859073 x[120,96] + 548.858472986434 x[120,97] + 572.5418023411041 x[120,98] + 16.738766412134467 x[120,99] + 14.72135435345543 x[120,100] + 44.32588693980079 x[120,101] + 44.331299665135035 x[120,102] + 54.59830009258534 x[120,103] + 72.06189456987656 x[120,104] + 59.333434503659106 x[120,105] + 53.17272120175912 x[120,106] + 96.53039747664981 x[120,107] + 37.910957215559726 x[120,108] + 55.121738180140895 x[120,109] + 45.033620118751266 x[120,110] + 51.87561419395441 x[120,111] + 50.36519656469144 x[120,112] + 56.079144938203235 x[120,113] + 71.6495037317078 x[120,114] + 109.0949179247136 x[120,115] + 21.048234367756358 x[120,116] + 47.38923295433258 x[120,117] + 30.046285161397243 x[120,118] + 21.681286885238233 x[120,119]

# %%
# DFJ iterativo agregando cortes hasta 1 componente
iteracion = 1
cortes_totales = 0
mejor_costo = Inf
mejor_x = nothing
t0 = time()

# Pequeños cortes iniciales para evitar 2-ciclos triviales
for i in 1:min(n, 8)
    for j in i+1:min(n, i+2)
        @constraint(model, x[i,j] + x[j,i] <= 1)
    end
end

println("Iniciando DFJ…")
while true
    println("\n--- Iteracion $iteracion ---")
    optimize!(model)

    term = termination_status(model)
    if !(term in (MOI.OPTIMAL, MOI.TIME_LIMIT)) && !has_values(model)
        error("El solver no retorno solucion valida. status = $term")
    end

    xvals = value.(x)
    comps = componentes_from_x(xvals; thr=0.5)
    println(" Componentes encontradas: ", length(comps))

    if length(comps) == 1
        costo = objective_value(model)
        println(" Tour factible DFJ. Costo (solver): ", round(costo, digits=3))
        mejor_costo = costo
        mejor_x = xvals
        break
    end

    # agregar como max 2 cortes por iteración
    nuevos = 0
    for S in comps
        nuevos += agregar_corte!(model, x, S)
        if nuevos >= 2; break; end
    end
    cortes_totales += nuevos
    println(" Cortes agregados en la iteración: $nuevos  |  Total: $cortes_totales")

    # afinar el gap después de algunas iteraciones
    if iteracion == 3
        set_optimizer_attribute(model, "mip_rel_gap", 0.2)
    end

    iteracion += 1
    if time() - t0 > 1200  # 20 minutos tope razonable
        println(" Límite de tiempo global alcanzado, saliendo…")
        break
    end
end

println("\nDFJ terminado en $(round(time()-t0, digits=1))s. Cortes totales: $cortes_totales")
# Out:
# Iniciando DFJ…
#
# --- Iteracion 1 ---
# Running HiGHS 1.11.0 (git hash: 364c83a51e): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 376 rows; 14400 cols; 28952 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 256 rows, 14280 cols, 28592 nonzeros  0s
# 256 rows, 14280 cols, 28592 nonzeros  0s
#
# Solving MIP model with:
#    256 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    28592 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            48031.371423       Large        0      0      0         0     0.1s
#  T       0       0         0   0.00%   0               1804.181177      100.00%        0      0      0       231     0.2s
#          1       0         1 100.00%   1804.181177     1804.181177        0.00%        0      0      0       231     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      1804.18117688
#   Dual bound        1804.18117688
#   Gap               0% (tolerance: 50%)
#   P-D integral      0.0329239368439
#   Solution status   feasible
#                     1804.18117688 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.16 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     231 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
#  Componentes encontradas: 56
#  Cortes agregados en la iteración: 2  |  Total: 2
#
# --- Iteracion 2 ---
# MIP  has 378 rows; 14400 cols; 29424 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 258 rows, 14280 cols, 29064 nonzeros  0s
# 258 rows, 14280 cols, 29064 nonzeros  0s
#
# Solving MIP model with:
#    258 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    29064 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            49034.13609        Large        0      0      0         0     0.1s
#  T       0       0         0   0.00%   0               1804.708271      100.00%        0      0      0       222     0.2s
#          1       0         1 100.00%   1804.708271     1804.708271        0.00%        0      0      0       222     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      1804.70827086
#   Dual bound        1804.70827086
#   Gap               0% (tolerance: 50%)
#   P-D integral      0.0320980548859
#   Solution status   feasible
#                     1804.70827086 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.17 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     222 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
#  Componentes encontradas: 55
#  Cortes agregados en la iteración: 2  |  Total: 4
#
# --- Iteracion 3 ---
# MIP  has 380 rows; 14400 cols; 30352 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 260 rows, 14280 cols, 29992 nonzeros  0s
# 260 rows, 14280 cols, 29758 nonzeros  0s
#
# Solving MIP model with:
#    260 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    29758 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            46603.90884        Large        0      0      0         0     0.1s
#  T       0       0         0   0.00%   0               1806.393444      100.00%        0      0      0       227     0.2s
#          1       0         1 100.00%   1806.393444     1806.393444        0.00%        0      0      0       227     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      1806.39344402
#   Dual bound        1806.39344402
#   Gap               0% (tolerance: 50%)
#   P-D integral      0.0298562049866
#   Solution status   feasible
#                     1806.39344402 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.16 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     227 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
#  Componentes encontradas: 56
#  Cortes agregados en la iteración: 2  |  Total: 6
#
# --- Iteracion 4 ---
# MIP  has 382 rows; 14400 cols; 31054 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 262 rows, 14280 cols, 30694 nonzeros  0s
# 262 rows, 14280 cols, 30460 nonzeros  0s
#
# Solving MIP model with:
#    262 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    30460 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            48384.186244       Large        0      0      0         0     0.1s
#          0       0         0   0.00%   1810.605054     48384.186244      96.26%        0      0      5       235     0.2s
#  L       0       0         0   0.00%   1816.088464     1816.088464        0.00%       63      6      9       245     0.3s
#          1       0         1 100.00%   1816.088464     1816.088464        0.00%       63      6      9       249     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      1816.08846432
#   Dual bound        1816.08846432
#   Gap               0% (tolerance: 20%)
#   P-D integral      0.184190032808
#   Solution status   feasible
#                     1816.08846432 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.33 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     249 (total)
#                     0 (strong br.)
#                     10 (separation)
#                     4 (heuristics)
#  Componentes encontradas: 55
#  Cortes agregados en la iteración: 2  |  Total: 8
#
# --- Iteracion 5 ---
# MIP  has 384 rows; 14400 cols; 32204 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 264 rows, 14280 cols, 31844 nonzeros  0s
# 264 rows, 14280 cols, 31610 nonzeros  0s
#
# Solving MIP model with:
#    264 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    31610 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            49471.698945       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1810.605054     2507.972067       27.81%        0      0      0       225     0.2s
#  T       0       0         0   0.00%   1814.573178     1817.3069          0.15%       80      7      0       236     0.3s
#          1       0         1 100.00%   1817.3069       1817.3069          0.00%       80      7      0       236     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      1817.30689976
#   Dual bound        1817.30689976
#   Gap               0% (tolerance: 20%)
#   P-D integral      0.0591069907217
#   Solution status   feasible
#                     1817.30689976 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.28 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     236 (total)
#                     0 (strong br.)
#                     11 (separation)
#                     0 (heuristics)
#  Componentes encontradas: 55
#  Cortes agregados en la iteración: 2  |  Total: 10
#
# --- Iteracion 6 ---
# MIP  has 386 rows; 14400 cols; 32906 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 266 rows, 14280 cols, 32546 nonzeros  0s
# 266 rows, 14280 cols, 32312 nonzeros  0s
#
# Solving MIP model with:
#    266 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    32312 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            51217.108876       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1810.605054     5488.890869       67.01%        0      0      0       231     0.2s
#  L       0       0         0   0.00%   1825.819658     1825.819658        0.00%       98      6      6       241     0.4s
#          1       0         1 100.00%   1825.819658     1825.819658        0.00%       98      6      6       245     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      1825.81965795
#   Dual bound        1825.81965795
#   Gap               0% (tolerance: 20%)
#   P-D integral      0.15509447579
#   Solution status   feasible
#                     1825.81965795 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.38 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     245 (total)
#                     0 (strong br.)
#                     10 (separation)
#                     4 (heuristics)
#  Componentes encontradas: 55
#  Cortes agregados en la iteración: 2  |  Total: 12
#
# --- Iteracion 7 ---
# MIP  has 388 rows; 14400 cols; 34056 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 268 rows, 14280 cols, 33696 nonzeros  0s
# 268 rows, 14280 cols, 33462 nonzeros  0s
#
# Solving MIP model with:
#    268 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    33462 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            49186.99985        Large        0      0      0         0     0.2s
#          0       0         0   0.00%   1813.32806      49186.99985       96.31%        0      0      7       246     0.2s
#  L       0       0         0   0.00%   1826.454392     1826.454392        0.00%      145      6     15       261     0.5s
#          1       0         1 100.00%   1826.454392     1826.454392        0.00%      145      6     15       269     0.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      1826.45439176
#   Dual bound        1826.45439176
#   Gap               0% (tolerance: 20%)
#   P-D integral      0.270626552182
#   Solution status   feasible
#                     1826.45439176 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.46 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     269 (total)
#                     0 (strong br.)
#                     15 (separation)
#                     8 (heuristics)
#  Componentes encontradas: 54
#  Cortes agregados en la iteración: 2  |  Total: 14
#
# --- Iteracion 8 ---
# MIP  has 390 rows; 14400 cols; 35424 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 270 rows, 14280 cols, 35064 nonzeros  0s
# 270 rows, 14280 cols, 34830 nonzeros  0s
#
# Solving MIP model with:
#    270 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    34830 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            48192.894586       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1813.32806      4431.041014       59.08%        0      0      0       243     0.2s
#  L       0       0         0   0.00%   1828.687093     1828.687093        0.00%      213      8      9       266     0.8s
#          1       0         1 100.00%   1828.687093     1828.687093        0.00%      213      8      9       307     0.8s
#
# Solving report
#   Status            Optimal
#   Primal bound      1828.68709323
#   Dual bound        1828.68709323
#   Gap               0% (tolerance: 20%)
#   P-D integral      0.380453134715
#   Solution status   feasible
#                     1828.68709323 (objective)
#                     0 (bound viol.)
#                     1.33226762955e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.79 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 3
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     307 (total)
#                     0 (strong br.)
#                     23 (separation)
#                     41 (heuristics)
#  Componentes encontradas: 55
#  Cortes agregados en la iteración: 2  |  Total: 16
#
# --- Iteracion 9 ---
# MIP  has 392 rows; 14400 cols; 36352 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 272 rows, 14280 cols, 35992 nonzeros  0s
# 272 rows, 14280 cols, 35758 nonzeros  0s
#
# Solving MIP model with:
#    272 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    35758 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            47921.883897       Large        0      0      0         0     0.1s
#          0       0         0   0.00%   1813.32806      47921.883897      96.22%        0      0      5       245     0.2s
#  C       0       0         0   0.00%   1828.582886     4029.50438        54.62%      176      6     10       266     0.3s
#  L       0       0         0   0.00%   1831.26567      1831.26567         0.00%      199      9     10       272     0.7s
#          1       0         1 100.00%   1831.26567      1831.26567         0.00%      199      9     10       302     0.7s
#
# Solving report
#   Status            Optimal
#   Primal bound      1831.26567027
#   Dual bound        1831.26567027
#   Gap               0% (tolerance: 20%)
#   P-D integral      0.356770929676
#   Solution status   feasible
#                     1831.26567027 (objective)
#                     0 (bound viol.)
#                     4.4408920985e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.72 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 5
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     302 (total)
#                     0 (strong br.)
#                     27 (separation)
#                     30 (heuristics)
#  Componentes encontradas: 56
#  Cortes agregados en la iteración: 2  |  Total: 18
#
# --- Iteracion 10 ---
# MIP  has 394 rows; 14400 cols; 37280 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 274 rows, 14280 cols, 36920 nonzeros  0s
# 274 rows, 14280 cols, 36686 nonzeros  0s
#
# Solving MIP model with:
#    274 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    36686 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            48290.39543        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1813.32806      5075.242975       64.27%        0      0      0       247     0.2s
#  C       0       0         0   0.00%   1828.860031     2461.810664       25.71%      191      6      0       261     0.3s
#  L       0       0         0   0.00%   1831.64888      1831.900404        0.01%      254      8      0       268     0.5s
#          1       0         1 100.00%   1831.64888      1831.900404        0.01%      254      8      0       280     0.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      1831.90040408
#   Dual bound        1831.64888025
#   Gap               0.0137% (tolerance: 20%)
#   P-D integral      0.162983250891
#   Solution status   feasible
#                     1831.90040408 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.55 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 3
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     280 (total)
#                     0 (strong br.)
#                     21 (separation)
#                     12 (heuristics)
#  Componentes encontradas: 55
#  Cortes agregados en la iteración: 2  |  Total: 20
#
# --- Iteracion 11 ---
# MIP  has 396 rows; 14400 cols; 38430 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 276 rows, 14280 cols, 38070 nonzeros  0s
# 276 rows, 14280 cols, 37836 nonzeros  0s
#
# Solving MIP model with:
#    276 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    37836 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            48839.252064       Large        0      0      0         0     0.1s
#          0       0         0   0.00%   1813.32806      48839.252064      96.29%        0      0      7       240     0.2s
#  C       0       0         0   0.00%   1830.449532     4029.50438        54.57%      222      8     14       261     0.3s
#  L       0       0         0   0.00%   1833.359835     1833.359835        0.00%      302     14     14       282     0.9s
#          1       0         1 100.00%   1833.359835     1833.359835        0.00%      302     14     14       328     0.9s
#
# Solving report
#   Status            Optimal
#   Primal bound      1833.35983481
#   Dual bound        1833.35983481
#   Gap               0% (tolerance: 20%)
#   P-D integral      0.455661544049
#   Solution status   feasible
#                     1833.35983481 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.88 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 6
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     328 (total)
#                     0 (strong br.)
#                     42 (separation)
#                     46 (heuristics)
#  Componentes encontradas: 55
#  Cortes agregados en la iteración: 2  |  Total: 22
#
# --- Iteracion 12 ---
# MIP  has 398 rows; 14400 cols; 39798 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 278 rows, 14280 cols, 39438 nonzeros  0s
# 278 rows, 14280 cols, 39204 nonzeros  0s
#
# Solving MIP model with:
#    278 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    39204 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            47462.741681       Large        0      0      0         0     0.2s
#          0       0         0   0.00%   1813.32806      47462.741681      96.18%        0      0      6       237     0.2s
#  C       0       0         0   0.00%   1824.20112      7294.509385       74.99%      115      7      8       250     0.3s
#  L       0       0         0   0.00%   1830.895664     1833.994569        0.17%      186     15      8       277     0.7s
#          1       0         1 100.00%   1830.895664     1833.994569        0.17%      186     15      8       318     0.7s
#
# Solving report
#   Status            Optimal
#   Primal bound      1833.99456862
#   Dual bound        1830.89566367
#   Gap               0.169% (tolerance: 20%)
#   P-D integral      0.425424213137
#   Solution status   feasible
#                     1833.99456862 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.70 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     318 (total)
#                     0 (strong br.)
#                     40 (separation)
#                     41 (heuristics)
#  Componentes encontradas: 54
#  Cortes agregados en la iteración: 2  |  Total: 24
#
# --- Iteracion 13 ---
# MIP  has 400 rows; 14400 cols; 41380 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 280 rows, 14280 cols, 41020 nonzeros  0s
# 280 rows, 14280 cols, 40786 nonzeros  0s
#
# Solving MIP model with:
#    280 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    40786 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            45982.57933        Large        0      0      0         0     0.2s
#          0       0         0   0.00%   1813.32806      45982.57933       96.06%        0      0      3       233     0.2s
#  L       0       0         0   0.00%   1835.050125     1835.050125        0.00%      348     15      9       275     0.8s
#          1       0         1 100.00%   1835.050125     1835.050125        0.00%      348     15      9       303     0.8s
#
# Solving report
#   Status            Optimal
#   Primal bound      1835.05012457
#   Dual bound        1835.05012457
#   Gap               0% (tolerance: 20%)
#   P-D integral      0.644318200297
#   Solution status   feasible
#                     1835.05012457 (objective)
#                     0 (bound viol.)
#                     4.4408920985e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.84 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 5
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     303 (total)
#                     0 (strong br.)
#                     42 (separation)
#                     28 (heuristics)
#  Componentes encontradas: 53
#  Cortes agregados en la iteración: 2  |  Total: 26
#
# --- Iteracion 14 ---
# MIP  has 402 rows; 14400 cols; 43378 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 282 rows, 14280 cols, 43018 nonzeros  0s
# 282 rows, 14280 cols, 42784 nonzeros  0s
#
# Solving MIP model with:
#    282 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    42784 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            46746.5787         Large        0      0      0         0     0.2s
#          0       0         0   0.00%   1813.32806      46746.5787        96.12%        0      0      3       248     0.2s
#  L       0       0         0   0.00%   1840.024377     1840.024377        0.00%      360     24     11       418     2.0s
#  T       0       0         0   0.00%   1840.024377     1840.024377        0.00%      360     24     11       571     2.0s
#          1       0         1 100.00%   1840.024377     1840.024377        0.00%      299     24     11       571     2.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      1840.02437729
#   Dual bound        1840.02437729
#   Gap               0% (tolerance: 20%)
#   P-D integral      1.70627069577
#   Solution status   feasible
#                     1840.02437729 (objective)
#                     0 (bound viol.)
#                     1.66000546642e-12 (int. viol.)
#                     0 (row viol.)
#   Timing            1.98 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 6
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     571 (total)
#                     0 (strong br.)
#                     170 (separation)
#                     153 (heuristics)
#  Componentes encontradas: 52
#  Cortes agregados en la iteración: 2  |  Total: 28
#
# --- Iteracion 15 ---
# MIP  has 404 rows; 14400 cols; 45776 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 284 rows, 14280 cols, 45416 nonzeros  0s
# 284 rows, 14280 cols, 45182 nonzeros  0s
#
# Solving MIP model with:
#    284 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    45182 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            50250.58865        Large        0      0      0         0     0.2s
#          0       0         0   0.00%   1817.869397     50250.58865       96.38%        0      0      5       257     0.2s
#  C       0       0         0   0.00%   1839.526578     4101.804181       55.15%      282      8      5       300     0.4s
#  L       0       0         0   0.00%   1840.132393     1840.132393        0.00%      540     21      5       348     1.5s
#          1       0         1 100.00%   1840.132393     1840.132393        0.00%      540     21      5       401     1.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      1840.13239335
#   Dual bound        1840.13239335
#   Gap               0% (tolerance: 20%)
#   P-D integral      0.792361149203
#   Solution status   feasible
#                     1840.13239335 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1.50 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 6
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     401 (total)
#                     0 (strong br.)
#                     91 (separation)
#                     53 (heuristics)
#  Componentes encontradas: 54
#  Cortes agregados en la iteración: 2  |  Total: 30
#
# --- Iteracion 16 ---
# MIP  has 406 rows; 14400 cols; 47144 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 286 rows, 14280 cols, 46784 nonzeros  0s
# 286 rows, 14280 cols, 46550 nonzeros  0s
#
# Solving MIP model with:
#    286 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    46550 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            49287.863925       Large        0      0      0         0     0.2s
#  R       0       0         0   0.00%   1817.869397     4631.037319       60.75%        0      0      0       251     0.2s
#  L       0       0         0   0.00%   1835.856621     1840.496137        0.25%      368     18      8       295     1.3s
#          1       0         1 100.00%   1835.856621     1840.496137        0.25%      368     18      8       397     1.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      1840.49613689
#   Dual bound        1835.85662128
#   Gap               0.252% (tolerance: 20%)
#   P-D integral      0.662260603772
#   Solution status   feasible
#                     1840.49613689 (objective)
#                     0 (bound viol.)
#                     6.66133814775e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            1.28 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 5
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     397 (total)
#                     0 (strong br.)
#                     44 (separation)
#                     102 (heuristics)
#  Componentes encontradas: 54
#  Cortes agregados en la iteración: 2  |  Total: 32
#
# --- Iteracion 17 ---
# MIP  has 408 rows; 14400 cols; 48936 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 288 rows, 14280 cols, 48576 nonzeros  0s
# 288 rows, 14280 cols, 48342 nonzeros  0s
#
# Solving MIP model with:
#    288 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    48342 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            49621.963405       Large        0      0      0         0     0.2s
#  R       0       0         0   0.00%   1817.869397     3488.805319       47.89%        0      0      0       254     0.2s
#  L       0       0         0   0.00%   1840.415955     1840.937457        0.03%      414     23      8       358     2.0s
#          1       0         1 100.00%   1840.415955     1840.937457        0.03%      333     23      8       488     2.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      1840.93745666
#   Dual bound        1840.41595514
#   Gap               0.0283% (tolerance: 20%)
#   P-D integral      0.846842411213
#   Solution status   feasible
#                     1840.93745666 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1.98 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 6
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     488 (total)
#                     0 (strong br.)
#                     104 (separation)
#                     130 (heuristics)
#  Componentes encontradas: 53
#  Cortes agregados en la iteración: 2  |  Total: 34
#
# --- Iteracion 18 ---
# MIP  has 410 rows; 14400 cols; 50518 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 290 rows, 14280 cols, 50158 nonzeros  0s
# 290 rows, 14280 cols, 49924 nonzeros  0s
#
# Solving MIP model with:
#    290 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    49924 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            46042.737962       Large        0      0      0         0     0.2s
#  R       0       0         0   0.00%   1817.869397     1857.043301        2.11%        0      0      0       255     0.2s
#          1       0         1 100.00%   1817.869397     1857.043301        2.11%        0      0      0       255     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      1857.04330073
#   Dual bound        1817.86939713
#   Gap               2.11% (tolerance: 20%)
#   P-D integral      0.0378571175874
#   Solution status   feasible
#                     1857.04330073 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.24 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     255 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
#  Componentes encontradas: 52
#  Cortes agregados en la iteración: 2  |  Total: 36
#
# --- Iteracion 19 ---
# MIP  has 412 rows; 14400 cols; 53110 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 292 rows, 14280 cols, 52750 nonzeros  0s
# 292 rows, 14280 cols, 52516 nonzeros  0s
#
# Solving MIP model with:
#    292 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    52516 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            53900.69905        Large        0      0      0         0     0.2s
#          0       0         0   0.00%   1818.916479     53900.69905       96.63%        0      0      3       269     0.2s
#  C       0       0         0   0.00%   1834.448451     1921.790804        4.54%      159      7      3       294     0.4s
#          1       0         1 100.00%   1834.448451     1921.790804        4.54%      159      7      3       294     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      1921.79080374
#   Dual bound        1834.4484506
#   Gap               4.54% (tolerance: 20%)
#   P-D integral      0.148329448762
#   Solution status   feasible
#                     1921.79080374 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.37 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     294 (total)
#                     0 (strong br.)
#                     25 (separation)
#                     0 (heuristics)
#  Componentes encontradas: 53
#  Cortes agregados en la iteración: 2  |  Total: 38
#
# --- Iteracion 20 ---
# MIP  has 414 rows; 14400 cols; 53582 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 294 rows, 14280 cols, 53222 nonzeros  0s
# 293 rows, 14280 cols, 52518 nonzeros  0s
#
# Solving MIP model with:
#    293 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    52518 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            53900.69905        Large        0      0      0         0     0.2s
#          0       0         0   0.00%   1818.916479     53900.69905       96.63%        0      0      2       271     0.3s
#  C       0       0         0   0.00%   1834.737019     4856.434474       62.22%      174      7      4       308     0.4s
#  L       0       0         0   0.00%   1835.18298      1842.130861        0.38%      176      9      4       312     1.0s
#          1       0         1 100.00%   1835.18298      1842.130861        0.38%      176      9      4       460     1.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      1842.13086068
#   Dual bound        1835.18297991
#   Gap               0.377% (tolerance: 20%)
#   P-D integral      0.546429157608
#   Solution status   feasible
#                     1842.13086068 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1.03 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 3
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     460 (total)
#                     0 (strong br.)
#                     41 (separation)
#                     148 (heuristics)
#  Componentes encontradas: 53
# ...
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            47423.623791       Large        0      0      0         0     1.4s
#          0       0         0   0.00%   2288.953793     47423.623791      95.17%        0      0      2       366     1.6s
#  L       0       0         0   0.00%   2300.961292     2334.955084        1.46%      264     34      8       701    12.2s
#          1       0         1 100.00%   2300.961292     2334.955084        1.46%      207     34      8      1543    12.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      2334.95508401
#   Dual bound        2300.96129166
#   Gap               1.46% (tolerance: 20%)
#   P-D integral      10.2656810455
#   Solution status   feasible
#                     2334.95508401 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            12.25 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 7
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1543 (total)
#                     0 (strong br.)
#                     335 (separation)
#                     842 (heuristics)
#  Componentes encontradas: 46
#  Cortes agregados en la iteración: 2  |  Total: 316
#
# --- Iteracion 159 ---
# MIP  has 692 rows; 14400 cols; 534576 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 572 rows, 14280 cols, 534216 nonzeros  0s
# 571 rows, 14280 cols, 533512 nonzeros  0s
#
# Solving MIP model with:
#    571 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    533512 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            51387.035804       Large        0      0      0         0     1.4s
#          0       0         0   0.00%   2288.953793     51387.035804      95.55%        0      0      3       353     1.6s
#  L       0       0         0   0.00%   2299.619847     2335.242334        1.53%      219     24     10       497    11.5s
#          1       0         1 100.00%   2299.619847     2335.242334        1.53%      196     24     10      1358    11.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      2335.24233441
#   Dual bound        2299.61984673
#   Gap               1.53% (tolerance: 20%)
#   P-D integral      9.58242422565
#   Solution status   feasible
#                     2335.24233441 (objective)
#                     0 (bound viol.)
#                     1.18904885937e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            11.49 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 7
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1358 (total)
#                     0 (strong br.)
#                     144 (separation)
#                     861 (heuristics)
#  Componentes encontradas: 45
#  Cortes agregados en la iteración: 2  |  Total: 318
#
# --- Iteracion 160 ---
# MIP  has 694 rows; 14400 cols; 539184 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 574 rows, 14280 cols, 538824 nonzeros  0s
# 573 rows, 14280 cols, 538120 nonzeros  0s
#
# Solving MIP model with:
#    573 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    538120 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            51387.035804       Large        0      0      0         0     1.5s
#          0       0         0   0.00%   2288.953793     51387.035804      95.55%        0      0      4       371     1.7s
#  L       0       0         0   0.00%   2307.961521     2335.503134        1.18%      340     38     14       730    14.1s
#          1       0         1 100.00%   2307.961521     2335.503134        1.18%      249     38     14      1687    14.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      2335.50313391
#   Dual bound        2307.96152094
#   Gap               1.18% (tolerance: 20%)
#   P-D integral      12.0659675416
#   Solution status   feasible
#                     2335.50313391 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            14.16 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 7
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1687 (total)
#                     0 (strong br.)
#                     359 (separation)
#                     957 (heuristics)
#  Componentes encontradas: 44
#  Cortes agregados en la iteración: 2  |  Total: 320
#
# --- Iteracion 161 ---
# MIP  has 696 rows; 14400 cols; 544462 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 576 rows, 14280 cols, 544102 nonzeros  0s
# 575 rows, 14280 cols, 543398 nonzeros  0s
#
# Solving MIP model with:
#    575 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    543398 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            49585.595668       Large        0      0      0         0     1.4s
#          0       0         0   0.00%   2288.953793     49585.595668      95.38%        0      0      3       341     1.7s
#  L       0       0         0   0.00%   2298.409084     2335.528982        1.59%      162     30      9       520    12.2s
#          1       0         1 100.00%   2298.409084     2335.528982        1.59%      117     30      9      1347    12.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      2335.5289816
#   Dual bound        2298.4090837
#   Gap               1.59% (tolerance: 20%)
#   P-D integral      10.2759660811
#   Solution status   feasible
#                     2335.5289816 (objective)
#                     0 (bound viol.)
#                     5.6132876125e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            12.26 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 6
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1347 (total)
#                     0 (strong br.)
#                     179 (separation)
#                     827 (heuristics)
#  Componentes encontradas: 47
#  Cortes agregados en la iteración: 2  |  Total: 322
#
# --- Iteracion 162 ---
# MIP  has 698 rows; 14400 cols; 548924 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 578 rows, 14280 cols, 548564 nonzeros  0s
# 577 rows, 14280 cols, 547860 nonzeros  0s
#
# Solving MIP model with:
#    577 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    547860 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            47013.563953       Large        0      0      0         0     1.4s
#          0       0         0   0.00%   2288.953793     47013.563953      95.13%        0      0      2       337     1.7s
#  L       0       0         0   0.00%   2306.979505     2335.56713         1.22%      236     25      6       681    11.9s
#          1       0         1 100.00%   2306.979505     2335.56713         1.22%      222     25      6      1634    11.9s
#
# Solving report
#   Status            Optimal
#   Primal bound      2335.56712981
#   Dual bound        2306.97950476
#   Gap               1.22% (tolerance: 20%)
#   P-D integral      9.90139459415
#   Solution status   feasible
#                     2335.56712981 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            11.91 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 7
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1634 (total)
#                     0 (strong br.)
#                     344 (separation)
#                     953 (heuristics)
#  Componentes encontradas: 46
#  Cortes agregados en la iteración: 2  |  Total: 324
#
# --- Iteracion 163 ---
# MIP  has 700 rows; 14400 cols; 553532 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 580 rows, 14280 cols, 553172 nonzeros  0s
# 579 rows, 14280 cols, 552468 nonzeros  0s
#
# Solving MIP model with:
#    579 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    552468 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            48955.802867       Large        0      0      0         0     1.4s
#          0       0         0   0.00%   2288.953793     48955.802867      95.32%        0      0      6       336     1.7s
#  L       0       0         0   0.00%   2303.12496      2335.551346        1.39%      276     23     14       450    10.9s
#          1       0         1 100.00%   2303.12496      2335.551346        1.39%      276     23     14      1277    11.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      2335.55134612
#   Dual bound        2303.12496018
#   Gap               1.39% (tolerance: 20%)
#   P-D integral      9.00084031105
#   Solution status   feasible
#                     2335.55134612 (objective)
#                     0 (bound viol.)
#                     8.881784197e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            10.97 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 7
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1277 (total)
#                     0 (strong br.)
#                     114 (separation)
#                     827 (heuristics)
#  Componentes encontradas: 45
#  Cortes agregados en la iteración: 2  |  Total: 326
#
# --- Iteracion 164 ---
# MIP  has 702 rows; 14400 cols; 558420 nonzeros; 14400 integer variables (14400 binary)
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+00, 9e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 582 rows, 14280 cols, 558060 nonzeros  0s
# 581 rows, 14280 cols, 557356 nonzeros  0s
#
# Solving MIP model with:
#    581 rows
#    14280 cols (14280 binary, 0 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    557356 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            48955.802867       Large        0      0      0         0     1.4s
#          0       0         0   0.00%   2288.953793     48955.802867      95.32%        0      0      2       309     1.7s
#  L       0       0         0   0.00%   2304.825858     2335.766684        1.32%      226     28      6       602    11.9s
#          1       0         1 100.00%   2304.825858     2335.766684        1.32%      185     28      6      1438    11.9s
#
# Solving report
#   Status            Optimal
#   Primal bound      2335.76668379
#   Dual bound        2304.82585776
#   Gap               1.32% (tolerance: 20%)
#   P-D integral      9.92145936639
#   Solution status   feasible
#                     2335.76668379 (objective)
#                     0 (bound viol.)
#                     4.39870362356e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            11.90 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 7
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1438 (total)
#                     0 (strong br.)
#                     293 (separation)
#                     836 (heuristics)
#  Componentes encontradas: 48
#  Cortes agregados en la iteración: 2  |  Total: 328
#  Límite de tiempo global alcanzado, saliendo…
#
# DFJ terminado en 1203.7s. Cortes totales: 328

# %%
# Heurística de Vecino Más Cercano (por si no hay incumbente)
function nearest_neighbor_tour(D::Matrix{Float64}; start::Int=1)
    n = size(D,1)
    unvis = trues(n)
    tour = Int[]
    cur = start
    for _ in 1:n
        push!(tour, cur); unvis[cur] = false
        if any(unvis)
            best = 0
            bestd = Inf
            @inbounds for j in 1:n
                if unvis[j] && D[cur,j] < bestd
                    best = j; bestd = D[cur,j]
                end
            end
            cur = best
        end
    end
    return tour
end

# Si tour_from_x devuelve varios ciclos (longitud < n), completa el tour greedy
function completar_tour_si_falta(tour::Vector{Int}, D::Matrix{Float64})
    n = size(D,1)
    if length(tour) == n
        return tour
    end
    pend = setdiff(1:n, tour)
    cur = tour[end]
    while !isempty(pend)
        # escoger el más cercano al 'cur'
        idx = 1
        best = pend[idx]
        bestd = D[cur, best]
        for k in 2:length(pend)
            if D[cur, pend[k]] < bestd
                idx = k; best = pend[k]; bestd = D[cur, pend[k]]
            end
        end
        push!(tour, best)
        cur = best
        deleteat!(pend, idx)
    end
    return tour
end
# Out:
# completar_tour_si_falta (generic function with 1 method)

# %%
# si no hubo incumbente (muy raro), usa heurística NN
tour_dfj = if mejor_x === nothing
    @warn "DFJ terminó sin incumbente; usando heurística de vecino más cercano."
    nearest_neighbor_tour(distancias; start=1)
else
    t = tour_from_x(mejor_x)
    completar_tour_si_falta(t, distancias)
end

costo_dfj_real = costo_tour(tour_dfj, distancias)

tour_2opt = copy(tour_dfj)
two_opt!(tour_2opt, distancias)
costo_2opt = costo_tour(tour_2opt, distancias)

usar_2opt = costo_2opt + 1e-6 < costo_dfj_real
tour_final = usar_2opt ? tour_2opt : tour_dfj
costo_final = usar_2opt ? costo_2opt : costo_dfj_real

println("\n=======================")
println("Costo DFJ real  : ", round(costo_dfj_real, digits=3))
println("Costo 2-opt     : ", round(costo_2opt, digits=3))
println("DECISIÓN        : ", usar_2opt ? "Usar 2-opt" : "Usar DFJ")
println("Costo FINAL     : ", round(costo_final, digits=3))
# Out:
# ┌ Warning: DFJ terminó sin incumbente; usando heurística de vecino más cercano.
# └ @ Main c:\Users\MSI\Desktop\info\Escritorio\UVG\8vo Semestre\Modelacion y Sinulacion\Proyectos\Proyecto 1\PROY1_MODSIM\propio\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W6sZmlsZQ==.jl:3
# =======================
# Costo DFJ real  : 3939.288
# Costo 2-opt     : 3574.705
# DECISIÓN        : Usar 2-opt
# Costo FINAL     : 3574.705

# %%
# guardar TOUR, costo y figura
function write_tsplib_tour(path::AbstractString, ids_1based::Vector{Int}; name="DFJ_SOLUTION")
    open(path, "w") do f
        println(f, "NAME: $name")
        println(f, "TYPE: TOUR")
        println(f, "DIMENSION: $(length(ids_1based))")
        println(f, "TOUR_SECTION")
        for v in ids_1based; println(f, v); end
        println(f, -1)
        println(f, "EOF")
    end
end

# ids reales (TSPLIB) en orden del tour
ids_tour_1based = [ids[i] for i in tour_final]

tour_path  = joinpath(OUTPUT_DIR, "tour_dfj_$(INSTANCE_NAME).tour")
costo_path = joinpath(OUTPUT_DIR, "costo_dfj_$(INSTANCE_NAME).txt")
write_tsplib_tour(tour_path, ids_tour_1based; name="$(INSTANCE_NAME)_DFJ")
open(costo_path, "w") do f; println(f, @sprintf("%.6f", costo_final)); end

# figura
xs, ys = coords[:,1], coords[:,2]
ord = vcat(tour_final, tour_final[1])
p = plot(xs[ord], ys[ord], lw=2, marker=:circle, legend=false, title="TSP $(INSTANCE_NAME) – DFJ")
scatter!(xs, ys)
png_path = joinpath(OUTPUT_DIR, "tour_dfj_$(INSTANCE_NAME).png")
savefig(p, png_path)

println("\nArchivos guardados:")
println(" - ", tour_path)
println(" - ", costo_path)
println(" - ", png_path)
# Out:
# Archivos guardados:
#  - output\archipelago120\tour_dfj_archipelago120.tour
#  - output\archipelago120\costo_dfj_archipelago120.txt
#  - output\archipelago120\tour_dfj_archipelago120.png
